# %%
이 문제를 보고 어떻게 최소공배, 최대공약, DFS를 떠올리는지 그 발상 메커니즘 알아내기

# %%
N = int(input())
A = [[] for _ in range(N)]
visited = [False] * (N)
D = [0] * N
lcm = 1

def gcd(a,b):
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

def DFS(v):
